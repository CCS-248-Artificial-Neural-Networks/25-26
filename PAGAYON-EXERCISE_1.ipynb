# %% [markdown]
# Arthur John Pagayon
# BSCS 3-A AI

# %% [markdown]
# 1.(20 points) Determine whether the student passes (1) or fails (0) based on:
# a. Hours studied
# b. Hours of sleep
# c. Hours of free time
# Given weights w1 = 0.6, w2, 0.4, bias = -3
# Step function with a threshold of 1
#
# Predict the output of the following inputs:
# 1. (x1, x2) = (8, 7)
# 2. (x1, x2) = (3, 4)

# %%
def step_function(value, threshold=1):
    return 1 if value >= threshold else 0

def perceptron_pass_fail(x1, x2, w1=0.6, w2=0.4, bias=-3):
    weighted_sum = (x1 * w1) + (x2 * w2) + bias
    output = step_function(weighted_sum, threshold=1)
    result = "Pass" if output == 1 else "Fail"
    return weighted_sum, result

inputs = [(8, 7), (3, 4)]
for x1, x2 in inputs:
    ws, res = perceptron_pass_fail(x1, x2)
    print(f"Input ({x1}, {x2}) => Weighted Sum: {ws:.2f}, Result: {res}")
# Out:
# ✓ Perceptron class defined and ready to use!

# %% [markdown]
# 2. (20 points) Logic Gate Simulation. Given the following setup for a perceptron, compute its output and verify whether it acts as an AND gate.
# Given weights w1 = 1, w2 = 1, bias = -1.5
# Step function with a threshold of 0
# Inputs:
# (0,0), (0,1), (1,0), (1,1)

# %%
def perceptron_and(x1, x2, w1=1, w2=1, bias=-1.5):
    weighted_sum = (x1 * w1) + (x2 * w2) + bias
    output = step_function(weighted_sum, threshold=0)
    return weighted_sum, output

inputs = [(0,0), (0,1), (1,0), (1,1)]
for x1, x2 in inputs:
    ws, out = perceptron_and(x1, x2)
    print(f"Input ({x1}, {x2}) => Weighted Sum: {ws}, Output: {out}")
# Out:
#               🎓 PROBLEM 1: Student Pass/Fail Prediction
# ======================================================================
#
# 📋 Perceptron Settings:
#    • Weight for Study Hours (w₁): 0.6
#    • Weight for Sleep Hours (w₂): 0.4
#    • Bias: -3
#    • Threshold: 1
#    • Rule: Output = 1 if (0.6×study + 0.4×sleep - 3) ≥ 1, else 0
#
# 📊 Test Case 1: Hardworking & Well-Rested Student
#    Input: Study Hours = 8, Sleep Hours = 7
#    Calculation: (0.6 × 8) + (0.4 × 7) - 3 = 4.6
#    Is 4.6 ≥ 1? True
#    ✅ Result: PASS
#
# 📊 Test Case 2: Struggling Student
#    Input: Study Hours = 3, Sleep Hours = 4
#    Calculation: (0.6 × 3) + (0.4 × 4) - 3 = 0.4000
#    Is 0.4000 ≥ 1? False
#    ❌ Result: FAIL
#
# 💡 Insight: The first student passes because they studied hard AND got enough
#    sleep. The second student fails because they didn't meet the combined requirement.

# %% [markdown]
# 3. (60 points) Perceptron comparison (One vs All). Given the 3 perceptron, using the same input, compute the output and decided on the predicted class is the WINNER. If a tie is present, compare and get the highest weighted sum.
#
# Inputs = [0.5, -1, 2, 1, 0]
# Perceptron A Configuration:
# - Weights: WA = [1.0, -0.5, 0.2, 0.1, 0.0]
# - BiasA: 0.2
# Perceptron B
# - Weights: WB = [0.2, 0.2, 0.5, -0.4, 0.3]
# - BiasB: 0.0
# Perceptron C
# - Weights: WC = [-0.3, -0.1, 0.4, 0.0, 0.2]
# - BiasC: -0.6

# %%
def perceptron_output(inputs, weights, bias):
    weighted_sum = sum(x*w for x, w in zip(inputs, weights)) + bias
    output = step_function(weighted_sum, threshold=0)
    return weighted_sum, output

inputs = [0.5, -1, 2, 1, 0]

# Perceptron A
WA = [1.0, -0.5, 0.2, 0.1, 0.0]
wsA, outA = perceptron_output(inputs, WA, 0.2)

# Perceptron B
WB = [0.2, 0.2, 0.5, -0.4, 0.3]
wsB, outB = perceptron_output(inputs, WB, 0.0)

# Perceptron C
WC = [-0.3, -0.1, 0.4, 0.0, 0.2]
wsC, outC = perceptron_output(inputs, WC, -0.6)

print(f"A: Weighted Sum = {wsA}, Output = {outA}")
print(f"B: Weighted Sum = {wsB}, Output = {outB}")
print(f"C: Weighted Sum = {wsC}, Output = {outC}")

# Determine winner
results = {"A": (wsA, outA), "B": (wsB, outB), "C": (wsC, outC)}
active = {k: v for k, v in results.items() if v[1] == 1}

if len(active) == 1:
    print("Winner:", list(active.keys())[0])
elif len(active) > 1:
    # tie: choose highest weighted sum
    winner = max(active.items(), key=lambda x: x[1][0])[0]
    print("Winner after tie-break:", winner)
else:
    print("No perceptron fired (all outputs 0).")
# Out:
#                  🔌 PROBLEM 2: AND Gate Implementation
# ======================================================================
#
# 📋 Perceptron Settings:
#    • Weight for Input 1 (w₁): 1
#    • Weight for Input 2 (w₂): 1
#    • Bias: -1.5
#    • Threshold: 0
#
# 📊 AND Gate Truth Table:
#    --------------------------------------------------
#    Input 1      Input 2      Weighted Sum    Output
#    --------------------------------------------------
#    0            0                  -1.5       0          ✓
#    0            1                  -0.5       0          ✓
#    1            0                  -0.5       0          ✓
#    1            1                   0.5       1          ✓
#    --------------------------------------------------
#
# ✅ SUCCESS: This perceptron perfectly implements an AND gate!
#    The perceptron learned the AND logic correctly.
#
# 💡 Insight: The AND gate outputs 1 only when BOTH inputs are 1.
#    All other combinations output 0. This is exactly what we see above.

# %%
# Out:
#          🏆 PROBLEM 3: Multi-Class Classification (One vs All)
# ======================================================================
#
# 📥 Input Features (5 dimensions): [0.5, -1, 2, 1, 0]
#    (These could represent any features: price, quality, ratings, etc.)
#
# 🤖 Perceptron A (Candidate Class A)
#    --------------------------------------------------
#    Weights: [1.0, -0.5, 0.2, 0.1, 0.0]
#    Bias: 0.2
#    Weighted Sum: 1.7000
#    Output: 1 ✓
#    Confidence: 1.7000 (higher = more confident)
#
# 🤖 Perceptron B (Candidate Class B)
#    --------------------------------------------------
#    Weights: [0.2, 0.2, 0.5, -0.4, 0.3]
#    Bias: 0.0
#    Weighted Sum: 0.5000
#    Output: 1 ✓
#    Confidence: 0.5000
#
# 🤖 Perceptron C (Candidate Class C)
#    --------------------------------------------------
#    Weights: [-0.3, -0.1, 0.4, 0.0, 0.2]
#    Bias: -0.6
#    Weighted Sum: 0.1500
#    Output: 1 ✓
#    Confidence: 0.1500
#
# ======================================================================
#                            🏅 FINAL DECISION
# ======================================================================
#
# ⚖️  TIE DETECTED! Multiple perceptrons voted: ['A', 'B', 'C']
#    Weighted Sums:
#    - Perceptron A: 1.7000
#    - Perceptron B: 0.5000
#    - Perceptron C: 0.1500
#
#    🏆 Breaking the tie: Perceptron A has the highest confidence!
#    Winner Confidence Score: 1.7000
#
#    **FINAL PREDICTION: CLASS A**
#
# 💡 Insight: This voting mechanism allows us to combine multiple
#    simple classifiers to make more robust multi-class decisions.
